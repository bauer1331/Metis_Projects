# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
from seaborn import plt

from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict
import sklearn

from scipy import ndimage

from time import time
import re
import json 
import pickle

from glob import glob
import random
from PIL import Image

# %%
dogs = pd.read_csv('../insta/dogs.csv') #4586021 #1303
dogs.tail(2)
# Out:
#                                                    images  \
# 109489  [{'path': 'full/1ac2329d1222f77d552c246c0a55f5...
# 109490  [{'path': 'full/1180b1265d190b517d78fc1208c533...
#
#                                                image_urls  \
# 109489  http://scontent.cdninstagram.com/t51.2885-15/s...
# 109490  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                           user_url  comments  likes  \
# 109489  http://www.imgrum.org/user/marutaro/124317       5.0  157.0
# 109490  http://www.imgrum.org/user/marutaro/124317     313.0  766.0
#
#                         username caption
# 109489  Shinjiro Ono (@marutaro)      神輿
# 109490  Shinjiro Ono (@marutaro)      秋桜

# %%
# nora.likes.value_counts()

# %%
cats = pd.read_csv('../insta/cats.csv')
cats.tail(2)
# cats.columns
# Out:
#                    caption                                      user_url  \
# 52776  When I was young :)  http://www.imgrum.org/user/nala_cat/27467826
# 52777          #small#nala  http://www.imgrum.org/user/nala_cat/27467826
#
#                                                   images  \
# 52776  [{'path': 'full/db11a3375c2deb1ccf9ecc8ec51bd1...
# 52777  [{'path': 'full/15c2db24b8750dadf413724ca92d22...
#
#                     username  comments   likes  \
# 52776  nala_cat™ (@nala_cat)     949.0  4698.0
# 52777  nala_cat™ (@nala_cat)      57.0  2168.0
#
#                                               image_urls
# 52776  http://scontent.cdninstagram.com/t51.2885-15/s...
# 52777  http://scontent.cdninstagram.com/t51.2885-15/s...

# %%
cats2 = pd.read_csv('../insta/cats2.csv')
cats2 = cats2[['caption', 'user_url', 'images', 'username', 'comments', 'likes',
       'image_urls']]
cats2.tail(2)
# Out:
#                                                  caption  \
# 50951  Submitted by @bedifferent #catsofinstagram #ca...
# 50952  Submitted by @BrandonPeters #catsofinstagram #...
#
#                                                 user_url  \
# 50951  http://www.imgrum.org/user/cats_of_instagram/7...
# 50952  http://www.imgrum.org/user/cats_of_instagram/7...
#
#                                                   images  \
# 50951  [{'checksum': 'c7f4d58984e7e4e39e2a91aff68d513...
# 50952  [{'checksum': '479dc292c4bfb143819630e207e3830...
#
#                                      username  comments  likes  \
# 50951  Cats of Instagram (@cats_of_instagram)      12.0  309.0
# 50952  Cats of Instagram (@cats_of_instagram)     177.0  777.0
#
#                                               image_urls
# 50951  http://scontent.cdninstagram.com/t51.2885-15/s...
# 50952  http://scontent.cdninstagram.com/t51.2885-15/s...

# %%
cats = cats.append(cats2)
cats.tail(2)
# Out:
#                                                  caption  \
# 50951  Submitted by @bedifferent #catsofinstagram #ca...
# 50952  Submitted by @BrandonPeters #catsofinstagram #...
#
#                                                 user_url  \
# 50951  http://www.imgrum.org/user/cats_of_instagram/7...
# 50952  http://www.imgrum.org/user/cats_of_instagram/7...
#
#                                                   images  \
# 50951  [{'checksum': 'c7f4d58984e7e4e39e2a91aff68d513...
# 50952  [{'checksum': '479dc292c4bfb143819630e207e3830...
#
#                                      username  comments  likes  \
# 50951  Cats of Instagram (@cats_of_instagram)      12.0  309.0
# 50952  Cats of Instagram (@cats_of_instagram)     177.0  777.0
#
#                                               image_urls
# 50951  http://scontent.cdninstagram.com/t51.2885-15/s...
# 50952  http://scontent.cdninstagram.com/t51.2885-15/s...

# %%
test = dogs.username
b = re.search(r"^([^\(]*)\(*", test[0])
a = re.search(r'\(@[^)]*\)', test[0])
b.group(0)
# test[0]
# Out:
# 'Shinjiro Ono ('

# %%
dogs['rating']=0
cats['rating']=0

# %%
def getName(row):
    a = re.search(r"^([^\(]*)\(*", row.username)
    return a.group(0)[:-1]

def getUsername(row):
    a = re.search(r'\(@[^)]*\)', row.username)
    return a.group(0)[2:-1]

# %%
def notNull(df):
    df = df[(df['username'].notnull())]
    df = df[(df['images'].notnull())]
    df = df[(df['likes'].notnull())].reset_index()
    df["name"] = df.apply(getName,axis=1)
    df["username"] = df.apply(getUsername,axis=1)
    return df

# %%
dogs = notNull(dogs)
cats = notNull(cats)

# %%
dogs.head(3)
# Out:
#    index                                             images  \
# 0     39  [{'path': 'full/f1d03d5c125ff5aed6f424e5101b69...
# 1     40  [{'path': 'full/d715b03d65488c2b52ecc506c0101c...
# 2     41  [{'path': 'full/a51591aa1e1f719955611da044f344...
#
#                                           image_urls  \
# 0  http://scontent.cdninstagram.com/t51.2885-15/s...
# 1  http://scontent.cdninstagram.com/t51.2885-15/s...
# 2  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                             user_url  comments    likes  \
# 0         http://www.imgrum.org/user/marutaro/124317     403.0  79232.0
# 1  http://www.imgrum.org/user/smileytheblindthera...      94.0   6705.0
# 2     http://www.imgrum.org/user/tobypuff/1695009566      43.0   2162.0
#
#                    username  \
# 0                  marutaro
# 1  smileytheblindtherapydog
# 2                  tobypuff
#
#                                              caption  rating            name
# 0  I wish this rain would go away🙄🐶おはまる〜*\(^o^)/*...       0   Shinjiro Ono
# 1                     I love when friends stop by!!!       0  Joanne George
# 2              How belle's friends look like in 2017       0

# %%
cats.head(2)
# Out:
#    index                                            caption  \
# 0     17  /\m/\ONSTERs in closets are real 🚪😈 @algonquin...
# 1     18  Thanks again to our awesome friends @littergen...
#
#                                             user_url  \
# 0  http://www.imgrum.org/user/princessmonstertruc...
# 1  http://www.imgrum.org/user/princessmonstertruc...
#
#                                               images              username  \
# 0  [{'path': 'full/0cc6b49841d86de62f7f75742328eb...  princessmonstertruck
# 1  [{'path': 'full/d7517fa9d348e9802ecc2140d35f25...  princessmonstertruck
#
#    comments   likes                                         image_urls  \
# 0      23.0  4661.0  http://scontent.cdninstagram.com/t51.2885-15/s...
# 1      10.0  2172.0  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#    rating                     name
# 0       0  PrincessMonsterTruck ©
# 1       0  PrincessMonsterTruck ©

# %%
marutaro = dogs[dogs['username']=='marutaro'].likes
marutaro = list(marutaro)
len(marutaro)
# Out:
# 5114

# %%
posts = list(range(1,5114))
posts.sort(reverse=True)
marutaro = list(zip(posts, marutaro))
marutaro = pd.DataFrame(marutaro,columns=['posts', 'likes'])

# %%
plt.plot(marutaro['posts'],marutaro['likes'],label='Likes')
plt.legend(loc=2)
plt.title('Total Likes over Time')
plt.xlabel("Posts")
plt.ylabel("Count of Likes")

# %%
recent_marutaro = marutaro[100:150]
recent_mean = recent_marutaro.likes.mean()
plt.plot(recent_marutaro['posts'],recent_marutaro['likes'],label='Likes')
plt.axhline(y=recent_mean, color='r', linestyle='-', label = 'Average Likes = 73574')
plt.legend(loc=2)
plt.title('Recent Total Likes over Time')
plt.xlabel("Posts")
plt.ylabel("Count of Likes")
print(recent_mean)
# Out:
# 73574.18

# %%
dogs[dogs['username']=='marutaro'][100:150]#4676
# Out:
#       index                                             images  \
# 4070   5930  [{'path': 'full/44ea38accefee47f56f09d91969875...
# 4072   5933  [{'path': 'full/f0b5e767425a7068aa8458f6326676...
# 4075   5937  [{'path': 'full/5545c7f2b05f4355d1e304dcbe7669...
# 4076   5940  [{'path': 'full/9d7d1858b6ba4710983c165c3b6805...
# 4077   5946  [{'path': 'full/db3c7b44c14f549d307e39ba0e18ad...
# 4078   5947  [{'path': 'full/48b31508a08e72d18b82c427122c47...
# 4082   5958  [{'path': 'full/66cc00dd79e486e75f766e51e9136d...
# 4090   5974  [{'path': 'full/63e7de0c611b95661e1e32bed17a6e...
# 4091   5975  [{'path': 'full/8e296acaaccb131d41e173a638c7e8...
# 4408   6410  [{'path': 'full/8fa35e1a15cf3bd7ac3ab98c710c1a...
# 4410   6412  [{'path': 'full/8752796e98322e739747620a169a7f...
# 4411   6413  [{'path': 'full/67b2dd120980b0d4e6a77cd435262b...
# 4413   6415  [{'path': 'full/7f2e6efea50c379a6b9486e4dce201...
# 4425   6427  [{'path': 'full/d489cfd78b30358efcfb237ec63aee...
# 4426   6428  [{'path': 'full/99f41922c49596d5b582e25228a2c3...
# 4431   6433  [{'path': 'full/b3f56565bc4c3c878ad76e9b9f57c8...
# 4467   6477  [{'path': 'full/43523b8de4ec705391dccbb489bb10...
# 4468   6478  [{'path': 'full/ac0a0cf4f1ddc2f1699865b46fcc06...
# 4469   6479  [{'path': 'full/e2c84d4820184ccf778b9b9e3afe5d...
# 4470   6480  [{'path': 'full/b689bfd1fb385c2073a490cf97ee32...
# 4471   6484  [{'path': 'full/ae44781c24aae6dd15a233f96ad6fd...
# 4472   6486  [{'path': 'full/f7ea3876c49bd14978a83c6bddb630...
# 4473   6487  [{'path': 'full/68b709ee6e8b3ada8ca20c590841d6...
# 4674   6776  [{'path': 'full/93f73f76d349efa5ca0a95149a6144...
# 4675   6777  [{'path': 'full/bc2056edb54809d02dd1c105e0f2f1...
# 4676   6778  [{'path': 'full/b3acbd7fc2d93016033af1bffc055b...
# 4677   6779  [{'path': 'full/7130cd566aa2d7e74339d122046ae6...
# 4684   6786  [{'path': 'full/514a26f3729c32d4cb98c855a0aeb1...
# 4685   6787  [{'path': 'full/259137cc8f8d81e7d7f6ff9d4df692...
# 4686   6788  [{'path': 'full/a6b93039396ffb1789c2d69fe97719...
# 4695   6802  [{'path': 'full/f38c281f7ff121bcbf4ca33cbcd681...
# 4696   6803  [{'path': 'full/99b7a0ae6bcc4f47ee8d68e9a71ad4...
# 4697   6804  [{'path': 'full/0465bfb101260d002d558bdbbfc185...
# 4698   6805  [{'path': 'full/3bdc6d370502225ca067dcd91c6046...
# 4699   6806  [{'path': 'full/fdfa0222b1c2b4abd21e8ba2d5db0f...
# 4700   6807  [{'path': 'full/9525a60236bb98f430e730acd17940...
# 4701   6808  [{'path': 'full/6066288608a10efb869566f107ffd5...
# 4702   6818  [{'path': 'full/d94fde26d66dc7e176d66438469d27...
# 4703   6826  [{'path': 'full/7b82055d5c666e03aac50dbf5cb892...
# 4704   6827  [{'path': 'full/9167adbc8d183d5dcb3f2218ed309e...
# 4881   7094  [{'path': 'full/e8e12bc0500a318b78ebbc92b0b151...
# 4882   7095  [{'path': 'full/26e317afb25bf28c19538e13c12726...
# 4884   7097  [{'path': 'full/0f370606c65c09f45f22c54be04393...
# 4897   7110  [{'path': 'full/32d5cfc9f12fe14755bda9b20697a4...
# 4898   7111  [{'path': 'full/d5aaa688569e3f4e95fa373886da54...
# 4899   7112  [{'path': 'full/10864c1f73e8b428cba5173db7486c...
# 4905   7118  [{'path': 'full/e8698adf999996e07560a1496a838f...
# 4908   7121  [{'path': 'full/b0ec37ef35da31c53a633bcdcee12b...
# 5018   7330  [{'path': 'full/11c0225d35635354fa9672c7f715a9...
# 5024   7336  [{'path': 'full/60eef9e6227f416d2bba94b74e7418...
#
#                                              image_urls  \
# 4070  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4072  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4075  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4076  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4077  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4078  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4082  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4090  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4091  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4408  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4410  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4411  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4413  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4425  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4426  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4431  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4467  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4468  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4469  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4470  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4471  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4472  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4473  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4674  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4675  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4676  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4677  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4684  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4685  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4686  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4695  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4696  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4697  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4698  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4699  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4700  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4701  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4702  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4703  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4704  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4881  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4882  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4884  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4897  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4898  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4899  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4905  http://scontent.cdninstagram.com/t51.2885-15/s...
# 4908  http://scontent.cdninstagram.com/t51.2885-15/s...
# 5018  http://scontent.cdninstagram.com/t51.2885-15/s...
# 5024  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                         user_url  comments     likes  \
# 4070  http://www.imgrum.org/user/marutaro/124317     194.0   60123.0
# 4072  http://www.imgrum.org/user/marutaro/124317     989.0  119720.0
# 4075  http://www.imgrum.org/user/marutaro/124317     493.0   89800.0
# 4076  http://www.imgrum.org/user/marutaro/124317     216.0   62584.0
# 4077  http://www.imgrum.org/user/marutaro/124317     227.0   66530.0
# 4078  http://www.imgrum.org/user/marutaro/124317     308.0   69145.0
# 4082  http://www.imgrum.org/user/marutaro/124317     809.0   92163.0
# 4090  http://www.imgrum.org/user/marutaro/124317     327.0   79273.0
# 4091  http://www.imgrum.org/user/marutaro/124317     462.0   83682.0
# 4408  http://www.imgrum.org/user/marutaro/124317     259.0   60874.0
# 4410  http://www.imgrum.org/user/marutaro/124317     399.0   79161.0
# 4411  http://www.imgrum.org/user/marutaro/124317     346.0   71976.0
# 4413  http://www.imgrum.org/user/marutaro/124317    1316.0   53992.0
# 4425  http://www.imgrum.org/user/marutaro/124317     369.0   76430.0
# 4426  http://www.imgrum.org/user/marutaro/124317     251.0   69850.0
# 4431  http://www.imgrum.org/user/marutaro/124317     192.0   61167.0
# 4467  http://www.imgrum.org/user/marutaro/124317     238.0   56993.0
# 4468  http://www.imgrum.org/user/marutaro/124317     234.0   77481.0
# 4469  http://www.imgrum.org/user/marutaro/124317     313.0   80603.0
# 4470  http://www.imgrum.org/user/marutaro/124317     264.0   67766.0
# 4471  http://www.imgrum.org/user/marutaro/124317     446.0   46422.0
# 4472  http://www.imgrum.org/user/marutaro/124317     238.0   72188.0
# 4473  http://www.imgrum.org/user/marutaro/124317     208.0   67011.0
# 4674  http://www.imgrum.org/user/marutaro/124317     140.0   61374.0
# 4675  http://www.imgrum.org/user/marutaro/124317     196.0   73660.0
# 4676  http://www.imgrum.org/user/marutaro/124317    1366.0  167929.0
# 4677  http://www.imgrum.org/user/marutaro/124317     353.0   81796.0
# 4684  http://www.imgrum.org/user/marutaro/124317     232.0   72292.0
# 4685  http://www.imgrum.org/user/marutaro/124317     309.0   76919.0
# 4686  http://www.imgrum.org/user/marutaro/124317     310.0   74814.0
# 4695  http://www.imgrum.org/user/marutaro/124317     219.0   62001.0
# 4696  http://www.imgrum.org/user/marutaro/124317     168.0   65596.0
# 4697  http://www.imgrum.org/user/marutaro/124317     335.0   61839.0
# 4698  http://www.imgrum.org/user/marutaro/124317     318.0   60565.0
# 4699  http://www.imgrum.org/user/marutaro/124317     209.0   73209.0
# 4700  http://www.imgrum.org/user/marutaro/124317     196.0   66187.0
# 4701  http://www.imgrum.org/user/marutaro/124317     302.0   85567.0
# 4702  http://www.imgrum.org/user/marutaro/124317     266.0   73414.0
# 4703  http://www.imgrum.org/user/marutaro/124317     215.0   71035.0
# 4704  http://www.imgrum.org/user/marutaro/124317     169.0   67110.0
# 4881  http://www.imgrum.org/user/marutaro/124317     267.0   78537.0
# 4882  http://www.imgrum.org/user/marutaro/124317     338.0   78511.0
# 4884  http://www.imgrum.org/user/marutaro/124317     541.0   65045.0
# 4897  http://www.imgrum.org/user/marutaro/124317     410.0   75067.0
# 4898  http://www.imgrum.org/user/marutaro/124317     126.0   56482.0
# 4899  http://www.imgrum.org/user/marutaro/124317     525.0   75806.0
# 4905  http://www.imgrum.org/user/marutaro/124317     475.0   69538.0
# 4908  http://www.imgrum.org/user/marutaro/124317     365.0   82103.0
# 5018  http://www.imgrum.org/user/marutaro/124317     213.0   77820.0
# 5024  http://www.imgrum.org/user/marutaro/124317     278.0   59559.0
#
#       username                                            caption  rating  \
# 4070  marutaro  Good morning!✨🐶✨土曜日おはまる〜*\(^o^)/* 今日はどこ行くの？ いい...       0
# 4072  marutaro  Maru's outer perimeter is equivalent to 33 ora...       0
# 4075  marutaro  Please let me sleep 5more minutes 🐶😌もう少し寝かせてね\...       0
# 4076  marutaro  Good night! From my room✨🐶💤✨今日はね、パパがしつこいからワンルー...       0
# 4077  marutaro  Good morning!✨🐶✨おはまる〜*\(^o^)/* 今日も頑張って来てよね〜\n#...       0
# 4078  marutaro  Today's snack is TAIYAKI✨🐶✨Taiyaki are small J...       0
# 4082  marutaro  How do I look in this？✨🐶✨おつまる〜*\(^o^)/* 今日も寒いか...       0
# 4090  marutaro  Good night!!✨🐶💤✨そろそろ寝るよ〜*\(^o^)/*\n#今日どら焼き食べたか...       0
# 4091  marutaro  Would you like to eat DORAYAKI  together?✨🐶☺️✨...       0
# 4408  marutaro  God night!!✨🐶💤✨まるってこう見るとアゴのラインとかシュッとしてていい感じよね\...       0
# 4410  marutaro  Good morning!!✨🐶✨おはまる〜*\(^o^)/* お散歩から帰ってきたよ〜\n...       0
# 4411  marutaro  Let's go on a walk together.\n🐾🐶🐾とことことことこ。最近は2...       0
# 4413  marutaro  5月中旬に「みんなのくじ」にまるが登場！その記念にキャンペーン実施するよ〜*\(^o^)/*...       0
# 4425  marutaro  Be smiling on Monday ✨🐶☺️✨月曜日おはまる〜*\(^o^)/* 今週...       0
# 4426  marutaro  There was thin ice on my water bucket✨🐶❄️✨おはまる...       0
# 4431  marutaro  It is especially cold this morning. A deep fre...       0
# 4467  marutaro  With daddy on the cow!! ✨🐶👴🏻✨いでぼく行って来たよ〜*\(^o^...       0
# 4468  marutaro  おつまる〜*\(^o^)/* @igersjp さんと @recruit_holdings ...       0
# 4469  marutaro  Good night!!✨🐶✨また明日ね〜\n#明日パパと郵便局行こうかな\n#売ってるかな...       0
# 4470  marutaro  Smile bros.✨🐶🐶✨水曜日おつまる〜*\(^o^)/* 天気がいいからマックス君も...       0
# 4471  marutaro  My stamps has launched in today!✨🐶✨おはまる〜*\(^o^...       0
# 4472  marutaro  Good night!!✨🐶💤今日はパパのお布団に潜ってねよ〜っと\n#早い者勝ち\n#弱肉...       0
# 4473  marutaro  Be smiling ✨🐶😁✨おはまる〜*\(^o^)/* 今週も柴っていこ〜🤘🏻\n#月曜...       0
# 4674  marutaro  Waht's for dinner? ✨🐶✨おつまる〜*\(^o^)/* お散歩行って来たよ...       0
# 4675  marutaro  Is there anywhere that itches?✨🐶✨おはまる〜*\(^o^)/...       0
# 4676  marutaro  Would you like to try one?✨🐶🍊🐼✨おつまる〜*\(^o^)/* ...       0
# 4677  marutaro  It seems likely to snow.✨🐶⛄️✨雪降るかな〜\n#降るといいな\n...       0
# 4684  marutaro  Good night!✨🐶💤また明日ね〜*\(^o^)/*\n#スマホ逆さにしてみて\n#お...       0
# 4685  marutaro  Fly high!!✨🐶💨✨おはまる〜*\(^o^)/* 飛んでるよ〜\n#フワァって舞い上...       0
# 4686  marutaro  Good morning!! The sunnier it is, the colder i...       0
# 4695  marutaro  Did you make any New Year's resolutions?✨🐶✨おつま...       0
# 4696  marutaro  Good nigh!!✨🐶💤✨明日も晴れるといいな〜\n#練習したいし\n#パパのわがままボ...       0
# 4697  marutaro  Omikuji are paper fortunes that can be found a...       0
# 4698  marutaro  I want this time to continue forever..✨🐶⚽️✨おつま...       0
# 4699  marutaro  Good night!!✨🐶🐶✨柴田さんちょと背中お借りしますよ\n#はみ出しちゃうもので\...       0
# 4700  marutaro  I love the evening twilight time. ✨🐶✨黄昏時ってね「誰そ...       0
# 4701  marutaro  Kadomatsu 🎍🐶🎍are traditional New Year decorati...       0
# 4702  marutaro  I’m wiped out after the climb. I need to recha...       0
# 4703  marutaro  How are you doing?l I am very energeticz✨🎍🐶🎍✨h...       0
# 4704  marutaro  Good night!!✨🐶💤✨パパが酔っ払って遅くなっちゃった〜\n#今日は初夢見れるかな...       0
# 4881  marutaro  Mt. Fuji is the highest mountain in Japan.  Aw...       0
# 4882  marutaro  to see the sunrise on New Year's Day✨🐶🌞🎌✨初日の出〜...       0
# 4884  marutaro  Do you have any New Years resolutions? I want ...       0
# 4897  marutaro  TOSHIKOSHI SOBA \nHappy New Year’s Eve! Toshik...       0
# 4898  marutaro  カメラマンまる、京都の美しいイルミネーションに大興奮！まるが撮影した光のアートたちが ＠bo...       0
# 4899  marutaro  Puremium fluffy version✨🐶✨ 今年最後のおはまる〜*\(^o^)/*...       0
# 4905  marutaro  Faster! Faster!✨🐶💨✨ビューン！サッカー選手は速く走る事が重要なんだって〜\...       0
# 4908  marutaro  Good morning!!✨🐶✨おはまる〜*\(^o^)/* 今日は29日だね〜\n#みん...       0
# 5018  marutaro  Good night✨🐶🐶💤柴田さんもう少し向こう行って\n#狭いから\n#顔潰れてるよ\n...       0
# 5024  marutaro  今回、まるはイルミネーションを見に京都までびゅーんと旅行。冬の京都は超寒いから防寒対策もバッ...       0
#
#                name
# 4070  Shinjiro Ono
# 4072  Shinjiro Ono
# 4075  Shinjiro Ono
# 4076  Shinjiro Ono
# 4077  Shinjiro Ono
# 4078  Shinjiro Ono
# 4082  Shinjiro Ono
# 4090  Shinjiro Ono
# 4091  Shinjiro Ono
# 4408  Shinjiro Ono
# 4410  Shinjiro Ono
# 4411  Shinjiro Ono
# 4413  Shinjiro Ono
# 4425  Shinjiro Ono
# 4426  Shinjiro Ono
# 4431  Shinjiro Ono
# 4467  Shinjiro Ono
# 4468  Shinjiro Ono
# 4469  Shinjiro Ono
# 4470  Shinjiro Ono
# 4471  Shinjiro Ono
# 4472  Shinjiro Ono
# 4473  Shinjiro Ono
# 4674  Shinjiro Ono
# 4675  Shinjiro Ono
# 4676  Shinjiro Ono
# 4677  Shinjiro Ono
# 4684  Shinjiro Ono
# 4685  Shinjiro Ono
# 4686  Shinjiro Ono
# 4695  Shinjiro Ono
# 4696  Shinjiro Ono
# 4697  Shinjiro Ono
# 4698  Shinjiro Ono
# 4699  Shinjiro Ono
# 4700  Shinjiro Ono
# 4701  Shinjiro Ono
# 4702  Shinjiro Ono
# 4703  Shinjiro Ono
# 4704  Shinjiro Ono
# 4881  Shinjiro Ono
# 4882  Shinjiro Ono
# 4884  Shinjiro Ono
# 4897  Shinjiro Ono
# 4898  Shinjiro Ono
# 4899  Shinjiro Ono
# 4905  Shinjiro Ono
# 4908  Shinjiro Ono
# 5018  Shinjiro Ono
# 5024  Shinjiro Ono

# %%
# dogs.ix[4676,'pic_path']

# %%
# dogs.ix[4898,'pic_path']

# %%
early_marutaro = marutaro[5064:5114]
early_mean = early_marutaro.likes.mean()
plt.plot(early_marutaro['posts'],early_marutaro['likes'],label='Likes')
plt.axhline(y=early_mean, color='r', linestyle='-', label= 'Average Likes = 110')
plt.legend(loc=1)
plt.title('Early Total Likes over Time')
plt.xlabel("Posts")
plt.ylabel("Count of Likes")
print(early_mean)
# Out:
# 109.71428571428571

# %%
dogs[dogs['username']=='marutaro'][5014:5064]#76818
# Out:
#         index                                             images  \
# 76730  109367  [{'path': 'full/46a352f192d1ceb42b619c64676b1e...
# 76731  109368  [{'path': 'full/8b7955627b108d53acd8f3b2314184...
# 76732  109369  [{'path': 'full/a38da353cb89f8b36d062b26f3b420...
# 76733  109373  [{'path': 'full/ecd5dc9a8def78a4f6bded6f75484a...
# 76734  109374  [{'path': 'full/77a898668d79afecb27d0aa535359d...
# 76735  109375  [{'path': 'full/aa762cc9d4ebff8afbac30a6bf4c28...
# 76736  109376  [{'path': 'full/46e74c0305185d3685b357bb7d53b7...
# 76737  109377  [{'path': 'full/fd1f7bef680a052fa644a1008df78e...
# 76738  109378  [{'path': 'full/6fa7aae12e6ee0e9dc35a61d328b7e...
# 76739  109379  [{'path': 'full/5c2bdd41e6e92ebe246cfa7052bec6...
# 76740  109380  [{'path': 'full/6488ca2d49789d830604426435366b...
# 76741  109381  [{'path': 'full/f10629f617af0db2b5621cf96e904a...
# 76742  109382  [{'path': 'full/4da57d161d237a2f9b5812c97f062b...
# 76743  109383  [{'path': 'full/398ef5eae7e655cb7391849c766551...
# 76744  109384  [{'path': 'full/067781e080a3c01268a82e8357db05...
# 76745  109388  [{'path': 'full/5002a86b3d360e2e1eba00f460573e...
# 76746  109389  [{'path': 'full/248a84002e399cd6dc6c8a14102380...
# 76747  109390  [{'path': 'full/1c7ea5680e3156a2b78e4c036b76f2...
# 76748  109391  [{'path': 'full/80312af32df774ac130c23d98b82fa...
# 76749  109392  [{'path': 'full/a55c4a3bcb16d9447afaf6ee4e1854...
# 76750  109393  [{'path': 'full/87031958ecc072344da22667171b0c...
# 76751  109394  [{'path': 'full/59c25071c7166e41d1a9cfa6770c46...
# 76752  109395  [{'path': 'full/23c50cdf60ac2e7b92d191d2ccfbdd...
# 76753  109396  [{'path': 'full/0dc50122622bfb2d9e39aeee193742...
# 76754  109397  [{'path': 'full/e3993a2f40d0d4b448469d62bee664...
# 76755  109398  [{'path': 'full/27d32f92e3c72b733225cd6d8249b4...
# 76756  109402  [{'path': 'full/65e443b2bcf79b314c1312197aef97...
# 76757  109403  [{'path': 'full/fcaaf9274c5b3f771de28ff5f1a74d...
# 76758  109404  [{'path': 'full/c607b89b7a82a7764b119a1dab32ac...
# 76759  109405  [{'path': 'full/d9775fff27843b76a4b84226392aa0...
# 76760  109406  [{'path': 'full/592b36b1b1555f11b3122b1d7c4af8...
# 76761  109407  [{'path': 'full/bf3c07831a64a33075c44a714fdc46...
# 76762  109408  [{'path': 'full/1a72d70751ab22572ce9e83c3f4c6a...
# 76763  109409  [{'path': 'full/b21f54fca5dba1c66ed9c32c87c8b5...
# 76764  109410  [{'path': 'full/36779829b98a0bef4caf4bc1f20675...
# 76765  109411  [{'path': 'full/f8ac6764c9b7035d2c0bada0e9f889...
# 76766  109412  [{'path': 'full/16118b3ac5dde9eeafc893e6ec5fc6...
# 76767  109413  [{'path': 'full/783fdb1711630e6a864e76d6e45fe6...
# 76768  109414  [{'path': 'full/3d0223ad1311428b40a470cd384001...
# 76769  109418  [{'path': 'full/a086e378933ba81e2bac73ac31fd00...
# 76770  109419  [{'path': 'full/b02218291906089cee71d93f8a38a9...
# 76771  109420  [{'path': 'full/23d08afa69afd1f3b094a50a16e1e2...
# 76772  109421  [{'path': 'full/9a9a4be73c34553a2faa045bf6ffe6...
# 76773  109422  [{'path': 'full/10221cbc2dfe318f8598f71418f191...
# 76774  109423  [{'path': 'full/405ac58b07e1524d7a0d04e381483b...
# 76775  109424  [{'path': 'full/32455e47126f0096aa8aabf015e873...
# 76776  109425  [{'path': 'full/59d7a3b668525631a0ff27dc5bb752...
# 76777  109426  [{'path': 'full/e2dc8902932d82dc7ba475f2f4103b...
# 76778  109427  [{'path': 'full/3c864f6efade4aaf8a3ffabaee0087...
# 76779  109428  [{'path': 'full/ab71496640c550cf13f930523db61a...
#
#                                               image_urls  \
# 76730  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76731  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76732  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76733  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76734  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76735  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76736  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76737  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76738  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76739  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76740  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76741  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76742  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76743  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76744  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76745  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76746  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76747  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76748  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76749  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76750  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76751  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76752  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76753  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76754  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76755  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76756  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76757  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76758  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76759  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76760  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76761  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76762  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76763  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76764  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76765  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76766  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76767  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76768  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76769  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76770  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76771  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76772  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76773  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76774  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76775  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76776  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76777  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76778  http://scontent.cdninstagram.com/t51.2885-15/s...
# 76779  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                          user_url  comments  likes  username  \
# 76730  http://www.imgrum.org/user/marutaro/124317       7.0   48.0  marutaro
# 76731  http://www.imgrum.org/user/marutaro/124317       6.0  102.0  marutaro
# 76732  http://www.imgrum.org/user/marutaro/124317       3.0   62.0  marutaro
# 76733  http://www.imgrum.org/user/marutaro/124317       7.0   42.0  marutaro
# 76734  http://www.imgrum.org/user/marutaro/124317       3.0  123.0  marutaro
# 76735  http://www.imgrum.org/user/marutaro/124317       6.0  168.0  marutaro
# 76736  http://www.imgrum.org/user/marutaro/124317       0.0   33.0  marutaro
# 76737  http://www.imgrum.org/user/marutaro/124317       3.0  154.0  marutaro
# 76738  http://www.imgrum.org/user/marutaro/124317       3.0   37.0  marutaro
# 76739  http://www.imgrum.org/user/marutaro/124317       0.0   23.0  marutaro
# 76740  http://www.imgrum.org/user/marutaro/124317       3.0   78.0  marutaro
# 76741  http://www.imgrum.org/user/marutaro/124317       3.0  139.0  marutaro
# 76742  http://www.imgrum.org/user/marutaro/124317       0.0   39.0  marutaro
# 76743  http://www.imgrum.org/user/marutaro/124317       2.0   39.0  marutaro
# 76744  http://www.imgrum.org/user/marutaro/124317       3.0   50.0  marutaro
# 76745  http://www.imgrum.org/user/marutaro/124317       2.0   58.0  marutaro
# 76746  http://www.imgrum.org/user/marutaro/124317       4.0   80.0  marutaro
# 76747  http://www.imgrum.org/user/marutaro/124317       1.0   89.0  marutaro
# 76748  http://www.imgrum.org/user/marutaro/124317       2.0   64.0  marutaro
# 76749  http://www.imgrum.org/user/marutaro/124317       4.0  168.0  marutaro
# 76750  http://www.imgrum.org/user/marutaro/124317       4.0  180.0  marutaro
# 76751  http://www.imgrum.org/user/marutaro/124317       0.0   77.0  marutaro
# 76752  http://www.imgrum.org/user/marutaro/124317       9.0  212.0  marutaro
# 76753  http://www.imgrum.org/user/marutaro/124317       0.0   36.0  marutaro
# 76754  http://www.imgrum.org/user/marutaro/124317       0.0   28.0  marutaro
# 76755  http://www.imgrum.org/user/marutaro/124317       0.0   35.0  marutaro
# 76756  http://www.imgrum.org/user/marutaro/124317       1.0   27.0  marutaro
# 76757  http://www.imgrum.org/user/marutaro/124317       1.0   31.0  marutaro
# 76758  http://www.imgrum.org/user/marutaro/124317       0.0   31.0  marutaro
# 76759  http://www.imgrum.org/user/marutaro/124317       1.0   70.0  marutaro
# 76760  http://www.imgrum.org/user/marutaro/124317       3.0  124.0  marutaro
# 76761  http://www.imgrum.org/user/marutaro/124317       2.0  157.0  marutaro
# 76762  http://www.imgrum.org/user/marutaro/124317       0.0   24.0  marutaro
# 76763  http://www.imgrum.org/user/marutaro/124317       6.0  159.0  marutaro
# 76764  http://www.imgrum.org/user/marutaro/124317       1.0   45.0  marutaro
# 76765  http://www.imgrum.org/user/marutaro/124317      10.0  332.0  marutaro
# 76766  http://www.imgrum.org/user/marutaro/124317       1.0   38.0  marutaro
# 76767  http://www.imgrum.org/user/marutaro/124317       1.0  199.0  marutaro
# 76768  http://www.imgrum.org/user/marutaro/124317       6.0   56.0  marutaro
# 76769  http://www.imgrum.org/user/marutaro/124317       0.0   23.0  marutaro
# 76770  http://www.imgrum.org/user/marutaro/124317       5.0  192.0  marutaro
# 76771  http://www.imgrum.org/user/marutaro/124317       0.0   55.0  marutaro
# 76772  http://www.imgrum.org/user/marutaro/124317       0.0   19.0  marutaro
# 76773  http://www.imgrum.org/user/marutaro/124317       0.0   26.0  marutaro
# 76774  http://www.imgrum.org/user/marutaro/124317       5.0  210.0  marutaro
# 76775  http://www.imgrum.org/user/marutaro/124317       4.0   60.0  marutaro
# 76776  http://www.imgrum.org/user/marutaro/124317       0.0   27.0  marutaro
# 76777  http://www.imgrum.org/user/marutaro/124317       7.0  190.0  marutaro
# 76778  http://www.imgrum.org/user/marutaro/124317       2.0   29.0  marutaro
# 76779  http://www.imgrum.org/user/marutaro/124317       2.0  124.0  marutaro
#
#                      caption  rating           name
# 76730               大切にしたい場所       0  Shinjiro Ono
# 76731             おっは～(^O^)／       0  Shinjiro Ono
# 76732                    NaN       0  Shinjiro Ono
# 76733         Hasselblad SWC       0  Shinjiro Ono
# 76734              サンダルが大好物☆       0  Shinjiro Ono
# 76735                 こんにちわん       0  Shinjiro Ono
# 76736           おはようさん(^O^)／       0  Shinjiro Ono
# 76737                   Boys       0  Shinjiro Ono
# 76738                     豊作       0  Shinjiro Ono
# 76739               もうすぐ春ですね       0  Shinjiro Ono
# 76740               大迫力@伊丹空港       0  Shinjiro Ono
# 76741                    昼寝中       0  Shinjiro Ono
# 76742                  ジョナサン       0  Shinjiro Ono
# 76743               気さくなカエル。       0  Shinjiro Ono
# 76744                  Paris       0  Shinjiro Ono
# 76745                海においでよ！       0  Shinjiro Ono
# 76746        まるの幼馴染 リバー ♂ 3歳       0  Shinjiro Ono
# 76747             東京タワーの方が好き       0  Shinjiro Ono
# 76748                   辻堂海岸       0  Shinjiro Ono
# 76749            おはようございマッスル       0  Shinjiro Ono
# 76750                   こんちわ       0  Shinjiro Ono
# 76751                     親子       0  Shinjiro Ono
# 76752        菖蒲フェア開催中@辻堂海浜公園       0  Shinjiro Ono
# 76753          hors d'oeuvre       0  Shinjiro Ono
# 76754           Solid square       0  Shinjiro Ono
# 76755             サイクリング行きてー       0  Shinjiro Ono
# 76756                    Run       0  Shinjiro Ono
# 76757      Enjoy slow life!!       0  Shinjiro Ono
# 76758                  RX-78       0  Shinjiro Ono
# 76759                   ニャンコ       0  Shinjiro Ono
# 76760                  楽しいね☆       0  Shinjiro Ono
# 76761                   てへっ☆       0  Shinjiro Ono
# 76762        sidewalk artist       0  Shinjiro Ono
# 76763                 Friend       0  Shinjiro Ono
# 76764   Infrared Photography       0  Shinjiro Ono
# 76765                   who?       0  Shinjiro Ono
# 76766                 ア ヴァード       0  Shinjiro Ono
# 76767             今日～もいい天気～♬       0  Shinjiro Ono
# 76768               My Leica       0  Shinjiro Ono
# 76769             水道水でお願いします       0  Shinjiro Ono
# 76770                オヤツください       0  Shinjiro Ono
# 76771                    BMX       0  Shinjiro Ono
# 76772            恋人の鍵ありませんか？       0  Shinjiro Ono
# 76773  Look furtively around       0  Shinjiro Ono
# 76774            まるの毛が抜け始めた。       0  Shinjiro Ono
# 76775                  doors       0  Shinjiro Ono
# 76776               Mercedes       0  Shinjiro Ono
# 76777                  zzz..       0  Shinjiro Ono
# 76778                  IRONY       0  Shinjiro Ono
# 76779    Smile with snow-man       0  Shinjiro Ono

# %%
# dogs.ix[76765,'pic_path']

# %%
# dogs.ix[76819,'pic_path']

# %%
def makeJson(row):
    row = row[1:-1]
    json_acceptable_string = row.replace("'", "\"")
    return json.loads(json_acceptable_string)

# %%
def getPaths(meta_data):
    meta_data["images"] = meta_data.images.apply(makeJson)
    pic_path = []
    for i in range(len(meta_data)):
        pic_path.append(meta_data['images'][i]['path'][5:])
    meta_data['pic_path'] = pic_path

    checksum = []
    for i in range(len(meta_data)):
        checksum.append(meta_data['images'][i]['checksum'])
    meta_data['checksum'] = checksum 

    return meta_data.drop(['images','index'],1)

# %%
dogs = getPaths(dogs)
dogs.head(2)
# Out:
#                                           image_urls  \
# 0  http://scontent.cdninstagram.com/t51.2885-15/s...
# 1  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                             user_url  comments    likes  \
# 0         http://www.imgrum.org/user/marutaro/124317     403.0  79232.0
# 1  http://www.imgrum.org/user/smileytheblindthera...      94.0   6705.0
#
#                    username  \
# 0                  marutaro
# 1  smileytheblindtherapydog
#
#                                              caption  rating            name  \
# 0  I wish this rain would go away🙄🐶おはまる〜*\(^o^)/*...       0   Shinjiro Ono
# 1                     I love when friends stop by!!!       0  Joanne George
#
#                                        pic_path  \
# 0  f1d03d5c125ff5aed6f424e5101b692ec178d171.jpg
# 1  d715b03d65488c2b52ecc506c0101c7a35f7d627.jpg
#
#                            checksum
# 0  3a7005c12e4d0f0ef19613b6d9663b0c
# 1  ad4b22c9ca4563c2d6fc477dcb9f4051

# %%
cats = getPaths(cats)
cats.head(2)
# Out:
#                                              caption  \
# 0  /\m/\ONSTERs in closets are real 🚪😈 @algonquin...
# 1  Thanks again to our awesome friends @littergen...
#
#                                             user_url              username  \
# 0  http://www.imgrum.org/user/princessmonstertruc...  princessmonstertruck
# 1  http://www.imgrum.org/user/princessmonstertruc...  princessmonstertruck
#
#    comments   likes                                         image_urls  \
# 0      23.0  4661.0  http://scontent.cdninstagram.com/t51.2885-15/s...
# 1      10.0  2172.0  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#    rating                     name  \
# 0       0  PrincessMonsterTruck ©
# 1       0  PrincessMonsterTruck ©
#
#                                        pic_path  \
# 0  0cc6b49841d86de62f7f75742328ebcfa2ec04ef.jpg
# 1  d7517fa9d348e9802ecc2140d35f25f43ba3769e.jpg
#
#                            checksum
# 0  6ec7173ba299c5471fd6c16920b0efbf
# 1  313ddc6627520e45c0821e1c058bedb4

# %%
cats.likes.mean()
# Out:
# 17139.553797426062

# %%
def getRating(df):
    ratings = []
    ind = df.index.values
    mean = df.likes.mean()
    std = np.std(df.likes)
    print(mean,mean/2)
    for i in range(len(df)): 
        if df.likes[i]>=mean/4:
            ratings.append(1)
        else:
            ratings.append(0)
    zipped = list(zip(ind,ratings))
    rate = pd.DataFrame(zipped,columns=['ind', 'updated_rating'])
    rate.set_index(['ind'], inplace=True)
    df.rating.update(rate.updated_rating)
    return df

# %%
cat_usernames = cats.username.unique()
dog_usernames = dogs.username.unique()

# %%
print('dogs:'"\n",dogs.rating.value_counts())
print('cats:'"\n",cats.rating.value_counts())
# Out:
# dogs:
#  0    76830
# Name: rating, dtype: int64
# cats:
#  0    74827
# Name: rating, dtype: int64

# %%
# def ratePhotos(usernames, df):
#     t0 = time()
#     for i in usernames:
#         new_rated = getRating(i, df)
#         df.rating.update(new_rated.updated_rating)
#     print("done in %0.3fs." % (time() - t0))
#     return df

# %%
cats = getRating(cats)
# Out:
# 17139.553797426062 8569.776898713031

# %%
dogs = getRating(dogs)
# Out:
# 13852.595952102043 6926.297976051022

# %%
print('dogs:'"\n",dogs.rating.value_counts())
print('cats:'"\n",cats.rating.value_counts())
# Out:
# dogs:
#  0    42862
# 1    33968
# Name: rating, dtype: int64
# cats:
#  0    44100
# 1    30727
# Name: rating, dtype: int64

# %%
# cats[(cats['rating']==0) & (cats['username']=='princessmonstertruck')].image_urls[0]#then do 15

# %%
# sample_good_cats = cats[(cats['rating']==0)].sample(4995)
# sample_bad_cats = cats[(cats['rating']==1)].sample(4995)
# sample_cats = sample_good_cats.append(sample_bad_cats)

# %%
# sample_cats.tail(2)

# %%
# !pwd
# Out:
# /Users/bauer/ds/metis/metisgh/Metis_Projects/Instagram_Likes/Code

# %%
data_path = '../../../local_files/Projects/Instagram_Likes_Local/data/'
# sample_cats.to_csv(data_path+'sample_cats.csv', index = False)

# %%
cats[(cats['rating']==1) & (cats['username']=='princessmonstertruck')].image_urls[12]
# Out:
# 'http://scontent.cdninstagram.com/t51.2885-15/s480x480/e35/c0.30.1080.1080/17127161_387746678258578_8246530451783548928_n.jpg?ig_cache_key=MTQ2OTY1OTYxNDQyNDQ2ODI5NQ%3D%3D.2.c'

# %%
dogs[dogs['rating']==0].head()
# Out:
#                                           image_urls  \
# 2  http://scontent.cdninstagram.com/t51.2885-15/s...
# 3  http://scontent.cdninstagram.com/t51.2885-15/s...
# 6  http://scontent.cdninstagram.com/t51.2885-15/s...
# 7  http://scontent.cdninstagram.com/t51.2885-15/s...
# 8  http://scontent.cdninstagram.com/t51.2885-15/s...
#
#                                             user_url  comments   likes  \
# 2     http://www.imgrum.org/user/tobypuff/1695009566      43.0  2162.0
# 3     http://www.imgrum.org/user/tobypuff/1695009566      47.0  2956.0
# 6  http://www.imgrum.org/user/smileytheblindthera...      28.0  3044.0
# 7     http://www.imgrum.org/user/tobypuff/1695009566      24.0  2044.0
# 8     http://www.imgrum.org/user/tobypuff/1695009566      14.0  2348.0
#
#                    username  \
# 2                  tobypuff
# 3                  tobypuff
# 6  smileytheblindtherapydog
# 7                  tobypuff
# 8                  tobypuff
#
#                                              caption  rating            name  \
# 2              How belle's friends look like in 2017       0
# 3     When puff hungry he stare at you with big eyes       0
# 6  I knew today was going to be a great day!!! My...       0  Joanne George
# 7  Happy St Patrick's day!! Toby was wondering wh...       0
# 8                        Sit up straight little puff       0
#
#                                        pic_path  \
# 2  a51591aa1e1f719955611da044f34412412a3660.jpg
# 3  b187c7407cb52bc91dcb9ae186ac93b199cff8db.jpg
# 6  a952328b9fcb8fd45b970866316a369fba3e9e42.jpg
# 7  147c1dbb0e2937c51881d3b392fbf11defdbd9a5.jpg
# 8  11bd17719fa6733f67a31460b8302644d81569c2.jpg
#
#                            checksum
# 2  cadf807e95db49c35671979859e6ff78
# 3  3ea0caccb8c7c071fa79b3aad0a5516d
# 6  6360e0e095c6cdf4013810c37a3eec1f
# 7  083c07ece41258a2ebc9e31704f4b04e
# 8  4635a31a6a4d73e7ee1c0ecf4f873d09

# %%
cats_in = glob("../../../local_files/Projects/Instagram_Likes_Local/InstaImages/Cats_Original/full/*.jpg")
cats_out = '../../../local_files/Projects/Instagram_Likes_Local/InstaImages/Cats_2/'
dogs_in = glob("../../../local_files/Projects/Instagram_Likes_Local/InstaImages/Dogs_Original/full/*.jpg")
dogs_out = '../../../local_files/Projects/Instagram_Likes_Local/InstaImages/Dogs_2/'

# %%
# cats.pic_path

# %%
size = 224, 224

def sortPhotos(df, input_path, output_path):
    for c in input_path:
        img = Image.open(c)
        img.thumbnail(size, Image.ANTIALIAS)
    #     img = Image.fromarray(img)
        rating = df.loc[df['pic_path']==c[-44:]]['rating']
        if (rating == 1).any():
            if random.random() > .3:
                img.save(output_path+'train/above_average'+c[-45:])
            else: 
                img.save(output_path+'validation/above_average'+c[-45:])
        else:
            if random.random() > .3:
                img.save(output_path+'train/below_average'+c[-45:])
            else:
                img.save(output_path+'validation/below_average'+c[-45:])

# %%
sortPhotos(cats, cats_in, cats_out)

# %%
sortPhotos(dogs, dogs_in, dogs_out)
