# %%
# !KERAS_BACKEND=tensorflow python -c "from keras import backend"
# Out:
# Using TensorFlow backend.

# %%
import os
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
from keras.callbacks import ModelCheckpoint
from PIL import Image


from glob import glob
# Out:
# Using TensorFlow backend.

# %%
# dimensions of our images.
img_width, img_height = 150, 150

train_data_dir = 'Cats_alltime/train'
validation_data_dir = 'Cats_alltime/validation'

# %%
# used to rescale the pixel values from [0, 255] to [0, 1] interval
datagen = ImageDataGenerator(rescale=1./255)

# automagically retrieve images and their classes for train and validation sets
train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode='binary')

validation_generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 25660 images belonging to 2 classes.
# Found 10938 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Convolution2D(32, (3, 3), input_shape=(img_width, img_height,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model_vgg = Sequential()
model_vgg.add(ZeroPadding2D((1, 1), input_shape=(img_width, img_height,3)))
model_vgg.add(Convolution2D(64, (3, 3), activation='relu', name='conv1_1'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(64, (3, 3), activation='relu', name='conv1_2'))
model_vgg.add(MaxPooling2D((2, 2), strides=(2, 2)))

model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(128, (3, 3), activation='relu', name='conv2_1'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(128, (3, 3), activation='relu', name='conv2_2'))
model_vgg.add(MaxPooling2D((2, 2), strides=(2, 2)))

model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(256, (3, 3), activation='relu', name='conv3_1'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(256, (3, 3), activation='relu', name='conv3_2'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(256, (3, 3), activation='relu', name='conv3_3'))
model_vgg.add(MaxPooling2D((2, 2), strides=(2, 2)))

model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv4_1'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv4_2'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv4_3'))
model_vgg.add(MaxPooling2D((2, 2), strides=(2, 2)))

model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv5_1'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv5_2'))
model_vgg.add(ZeroPadding2D((1, 1)))
model_vgg.add(Convolution2D(512, (3, 3), activation='relu', name='conv5_3'))
model_vgg.add(MaxPooling2D((2, 2), strides=(2, 2)))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
nb_epoch = 30
nb_train_samples = 25660
nb_validation_samples = 10938

# %%
filepath="rajCatsalltime-weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
model.fit_generator(
        train_generator,
        samples_per_epoch=nb_train_samples//16, #40661 // batch_size
        nb_epoch=nb_epoch,
        validation_data=validation_generator,
        nb_val_samples=nb_validation_samples//16, #15502//batch_size
        callbacks=callbacks_list)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:7: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., validation_data=<keras.pre..., steps_per_epoch=100, epochs=30, callbacks=[<keras.ca..., validation_steps=683)`
# Epoch 1/30
# Epoch 00000: val_acc improved from -inf to 0.52952, saving model to rajCatsalltime-weights-improvement-00-0.53.hdf5
# 100/100 [==============================] - 281s - loss: 0.7237 - acc: 0.5012 - val_loss: 0.6922 - val_acc: 0.5295
# Epoch 2/30
# Epoch 00001: val_acc improved from 0.52952 to 0.53841, saving model to rajCatsalltime-weights-improvement-01-0.54.hdf5
# 100/100 [==============================] - 280s - loss: 0.6984 - acc: 0.5175 - val_loss: 0.6881 - val_acc: 0.5384
# Epoch 3/30
# Epoch 00002: val_acc improved from 0.53841 to 0.55585, saving model to rajCatsalltime-weights-improvement-02-0.56.hdf5
# 100/100 [==============================] - 280s - loss: 0.6944 - acc: 0.5175 - val_loss: 0.6854 - val_acc: 0.5559
# Epoch 4/30
# Epoch 00003: val_acc improved from 0.55585 to 0.55686, saving model to rajCatsalltime-weights-improvement-03-0.56.hdf5
# 100/100 [==============================] - 280s - loss: 0.6947 - acc: 0.5269 - val_loss: 0.6834 - val_acc: 0.5569
# Epoch 5/30
# Epoch 00004: val_acc improved from 0.55686 to 0.58204, saving model to rajCatsalltime-weights-improvement-04-0.58.hdf5
# 100/100 [==============================] - 281s - loss: 0.6805 - acc: 0.5487 - val_loss: 0.6764 - val_acc: 0.5820
# Epoch 6/30
# Epoch 00005: val_acc did not improve
# 100/100 [==============================] - 280s - loss: 0.6908 - acc: 0.5719 - val_loss: 0.6686 - val_acc: 0.5800
# Epoch 7/30
# Epoch 00006: val_acc did not improve
# 100/100 [==============================] - 280s - loss: 0.6815 - acc: 0.5537 - val_loss: 0.6817 - val_acc: 0.5266
# Epoch 8/30
# Epoch 00007: val_acc did not improve
# 100/100 [==============================] - 280s - loss: 0.6755 - acc: 0.5719 - val_loss: 0.6728 - val_acc: 0.5784
# Epoch 9/30
# Epoch 00008: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6670 - acc: 0.5825 - val_loss: 0.6634 - val_acc: 0.5806
# Epoch 10/30
# Epoch 00009: val_acc improved from 0.58204 to 0.60186, saving model to rajCatsalltime-weights-improvement-09-0.60.hdf5
# 100/100 [==============================] - 281s - loss: 0.6622 - acc: 0.5894 - val_loss: 0.6676 - val_acc: 0.6019
# Epoch 11/30
# Epoch 00010: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6801 - acc: 0.5675 - val_loss: 0.6748 - val_acc: 0.5587
# Epoch 12/30
# Epoch 00011: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6708 - acc: 0.5787 - val_loss: 0.6652 - val_acc: 0.5907
# Epoch 13/30
# Epoch 00012: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6626 - acc: 0.5913 - val_loss: 0.6673 - val_acc: 0.5876
# Epoch 14/30
# Epoch 00013: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6700 - acc: 0.5781 - val_loss: 0.6604 - val_acc: 0.5824
# Epoch 15/30
# Epoch 00014: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6856 - acc: 0.5644 - val_loss: 0.6783 - val_acc: 0.5964
# Epoch 16/30
# Epoch 00017: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6618 - acc: 0.6044 - val_loss: 0.6666 - val_acc: 0.5941
# Epoch 19/30
# Epoch 00018: val_acc improved from 0.60186 to 0.60232, saving model to rajCatsalltime-weights-improvement-18-0.60.hdf5
# 100/100 [==============================] - 281s - loss: 0.6628 - acc: 0.6025 - val_loss: 0.6582 - val_acc: 0.6023
# Epoch 20/30
# Epoch 00019: val_acc improved from 0.60232 to 0.61353, saving model to rajCatsalltime-weights-improvement-19-0.61.hdf5
# 100/100 [==============================] - 281s - loss: 0.6636 - acc: 0.5700 - val_loss: 0.6573 - val_acc: 0.6135
# Epoch 21/30
# Epoch 00020: val_acc improved from 0.61353 to 0.61404, saving model to rajCatsalltime-weights-improvement-20-0.61.hdf5
# 100/100 [==============================] - 281s - loss: 0.6697 - acc: 0.6181 - val_loss: 0.6586 - val_acc: 0.6140
# Epoch 22/30
# Epoch 00021: val_acc improved from 0.61404 to 0.61820, saving model to rajCatsalltime-weights-improvement-21-0.62.hdf5
# 100/100 [==============================] - 281s - loss: 0.6650 - acc: 0.6075 - val_loss: 0.6608 - val_acc: 0.6182
# Epoch 23/30
# Epoch 00022: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6854 - acc: 0.5894 - val_loss: 0.6600 - val_acc: 0.6090
# Epoch 24/30
# Epoch 00023: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6546 - acc: 0.5956 - val_loss: 0.6603 - val_acc: 0.6161
# Epoch 25/30
# Epoch 00024: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6564 - acc: 0.6256 - val_loss: 0.6590 - val_acc: 0.6076
# Epoch 26/30
# Epoch 00025: val_acc improved from 0.61820 to 0.62278, saving model to rajCatsalltime-weights-improvement-25-0.62.hdf5
# 100/100 [==============================] - 280s - loss: 0.6555 - acc: 0.6219 - val_loss: 0.6547 - val_acc: 0.6228
# Epoch 27/30
# Epoch 00026: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6601 - acc: 0.6250 - val_loss: 0.6519 - val_acc: 0.6225
# Epoch 28/30
# Epoch 00027: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6561 - acc: 0.6056 - val_loss: 0.6576 - val_acc: 0.6049
# Epoch 29/30
# Epoch 00028: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6627 - acc: 0.6081 - val_loss: 0.6693 - val_acc: 0.6074
# Epoch 30/30
# Epoch 00029: val_acc did not improve
# 100/100 [==============================] - 281s - loss: 0.6569 - acc: 0.6238 - val_loss: 0.6628 - val_acc: 0.6200

# %%
model.evaluate_generator(validation_generator, nb_validation_samples)
# Out:
# [0.66233366276991157, 0.62363074004409536]

# %%
nb_validation_samples/32
# Out:
# 341

# %%
val_predictions2 = model.predict_generator(validation_generator,342)

# %%
preds = pd.DataFrame(val_predictions2)
files = pd.DataFrame(validation_generator.filenames)
cats4_predictions = files.join(preds,lsuffix=0, rsuffix= 11594)
cats4_predictions.columns = ['path','probability']
cats4_predictions.head()
# Out:
#                                                path  probability
# 0  bad/fa2e588b07b893006e5272b3ee68b9a21eb373a2.jpg     0.543619
# 1  bad/254781d725d38b4f3b2ecc86d2455929742572cf.jpg     0.442421
# 2  bad/bb443ebcd470e45fb556dc806bd9d0277ec8cda7.jpg     0.480293
# 3  bad/848637621fde2c9a0626da72cd9a5f02cdb8d5e1.jpg     0.408011
# 4  bad/2847320db638da8ce08b87d46b5b9f5874d83ceb.jpg     0.600348

# %%
cats4_predictions.to_csv('cats_alltime_predictions.csv')
