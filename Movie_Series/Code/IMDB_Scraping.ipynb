# %%
import requests

url = 'http://www.imdb.com/title/tt4846340/?ref_=inth_ov_tt'

response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
#print(response.text)

# %%
page = response.text

# %%
page
# Out:
# '\n\n\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\nxmlns:og="http://ogp.me/ns#"\nxmlns:fb="http://www.facebook.com/2008/fbml">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt4846340?src=mdot">\n        \n    \n            <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>\n            <script type="text/javascript">\n                var ue_mid = "A1EVAM02EL8SFB"; \n                var ue_sn = "www.imdb.com";  \n                var ue_furl = "fls-na.amazon.com";\n                var ue_sid = "000-0000000-0000000";\n                var ue_id = "1F218TJ8KZ6BGHBE7RAV";\n                (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i){
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page,"lxml")

# %%
#print(soup())

# %%
#print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///title/tt4846340?src=mdot" name="apple-itunes-app"/>
#   <script type="text/javascript">
#    var ue_t0=window.ue_t0||+new Date();
#   </script>
#   <script type="text/javascript">
#    var ue_mid = "A1EVAM02EL8SFB";
#                 var ue_sn = "www.imdb.com";
#                 var ue_furl = "fls-na.amazon.com";
#                 var ue_sid = "000-0000000-0000000";
#                 var ue_id = "0CWJP4BCMBEXAR1CS50D";
# ...

# %%
print(soup.find('a'))
# Out:
# <a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home"></a>

# %%
print(soup.a)
# Out:
# <a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home"></a>

# %%
print(soup.a.prettify())
# Out:
# <a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home">
# </a>

# %%
//*[@id="titleStoryLine"]/div[2]/a[1]
itemprop="keywords">nasa<

# %%
soup.find_all(class_='itemprop')
# Out:
# [<span class="itemprop" itemprop="genre">Drama</span>,
#  <span class="itemprop" itemprop="name">Theodore Melfi</span>,
#  <span class="itemprop" itemprop="name">Allison Schroeder</span>,
#  <span class="itemprop" itemprop="name">Theodore Melfi</span>,
#  <span class="itemprop" itemprop="name">Taraji P. Henson</span>,
#  <span class="itemprop" itemprop="name">Octavia Spencer</span>,
#  <span class="itemprop" itemprop="name">Janelle Monáe</span>,
#  <td class="itemprop" itemprop="actor" itemscope="" itemtype="http://schema.org/Person">
#  <a href="/name/nm0378245/?ref_=tt_cl_t1" itemprop="url"> <span class="itemprop" itemprop="name">Taraji P. Henson</span>
#  </a> </td>,
#  <span class="itemprop" itemprop="name">Taraji P. Henson</span>,
#  <td class="itemprop" itemprop="actor" itemscope="" itemtype="http://schema.org/Person">
#  <a href="/name/nm0818055/?ref_=tt_cl_t2" itemprop="url"> <span class="itemprop" itemprop="name">Octavia Spencer</span>
#  </a> </td>,
# ...

# %%
itemps = soup.find_all(class_='itemprop',itemprop='keywords')

# %%
for i in itemps:
    print(i.text)
# Out:
# nasa
# african american
# based on a true story
# computer
# astronaut

# %%
links = []
for link in soup.find_all('a'):
    links.append(link)
print(links)
# Out:
# [<a class="navbarSprite" href="/?ref_=nv_home" id="home_img" title="Home"></a>, <a href="/?ref_=nv_home" title="Home">IMDb</a>, <a href="/search/">More</a>, <a href="/movies-in-theaters/?ref_=nv_tp_inth_1">Movies</a>, <a href="/chart/toptv/?ref_=nv_tp_tv250_2">TV</a>, <a href="/showtimes/?ref_=nv_tp_sh_3">Showtimes</a>, <a href="/movies-in-theaters/?ref_=nv_mv_inth_1">In Theaters</a>, <a href="/showtimes/?ref_=nv_mv_sh_2">Showtimes &amp; Tickets</a>, <a href="/trailers/?ref_=nv_mv_tr_3">Latest Trailers</a>, <a href="/movies-coming-soon/?ref_=nv_mv_cs_4">Coming Soon</a>, <a href="/calendar/?ref_=nv_mv_cal_5">Release Calendar</a>, <a href="/chart/top?ref_=nv_mv_250_6">Top Rated Movies</a>, <a href="/chart/top-indian-movies?ref_=nv_mv_250_in_7">Top Rated Indian Movies</a>, <a href="/chart/moviemeter?ref_=nv_mv_mpm_8">Most Popular Movies</a>, <a href="/chart/?ref_=nv_ch_cht_1">Box Office</a>, <a href="/search/title?count=100&amp;groups=oscar_best_picture_winners&amp;sort=year,desc&amp;re
# ...

# %%
soup.find('a')['href']
# Out:
# '/?ref_=nv_home'

# %%
for element in soup.find_all(class_='metacriticScore score_favorable titleReviewBarSubItem'):
    print(element.text,'\n')
# Out:
# 74

# %%
for element in soup.find_all(class_='imdbRating'):
    print(element,'\n')
# Out:
# <div class="imdbRating" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <div class="ratingValue">
# <strong title="7.9 based on 8,934 user ratings"><span itemprop="ratingValue">7.9</span></strong><span class="grey">/</span><span class="grey" itemprop="bestRating">10</span> </div>
# <a href="/title/tt4846340/ratings?ref_=tt_ov_rt"><span class="small" itemprop="ratingCount">8,934</span></a>
# <div class="hiddenImportant">
# <span itemprop="reviewCount">69 user</span>
# <span itemprop="reviewCount">132 critic</span>
# </div>
# </div>

# %%
for element in soup.find_all(class_='ratingValue'):
    print(element.text,'\n')
# Out:
# 7.9/10

# %%
#user_reviews = soup.find_all(class_='small',itemprop='ratingCount'
for element in soup.find_all(class_='small',itemprop='ratingCount'):
    print(element.text,'\n')
# Out:
# 8,934

# %%
for element in soup.find_all(itemprop='reviewCount'):
    print(element.text,'\n')
# Out:
# 69 user
#
# 132 critic

# %%
title_string = soup.find('title').text
print(title_string)
# Out:
# Hidden Figures (2016) - IMDb

# %%
title = title_string.split('(')[0].strip()
print(title)
# Out:
# Hidden Figures

# %%
year = title_string.split('(')[1].split(')')[0].strip()
print(year)
# Out:
# 2016

# %%
print(soup.find(text="Budget:"))
# Out:
# Budget:

# %%
import re
domestic_total_regex = re.compile('Budget:')
soup.find(text=domestic_total_regex)
# Out:
# 'Budget:'

# %%
budget_string = soup.find(text=re.compile('Budget:'))
print(budget_string)
# Out:
# Budget:

# %%
print (page)
# Out:
# <!DOCTYPE html>
# <html
# xmlns:og="http://ogp.me/ns#"
# xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///title/tt4846340?src=mdot">
#
#
#             <script type="text/javascript">var ue_t0=window.ue_t0||+new Date();</script>
#             <script type="text/javascript">
#                 var ue_mid = "A1EVAM02EL8SFB";
#                 var ue_sn = "www.imdb.com";
#                 var ue_furl = "fls-na.amazon.com";
#                 var ue_sid = "000-0000000-0000000";
#                 var ue_id = "1F218TJ8KZ6BGHBE7RAV";
# ...

# %%
a = re.search(r'Gross:</h4>[ ]+[$][0-9,]+', page)
b = re.search(r'[$][0-9,]+', a.group(0))
b.group(0)[1:]
# Out:
# '61,889,939'

# %%
a = re.search(r'Budget:</h4>[ ]+[$][0-9,]+', page)
b = re.search(r'[$][0-9,]+', a.group(0))
print(a,b.group(0)[1:])
# Out:
# <_sre.SRE_Match object; span=(173192, 173223), match='Budget:</h4>        $25,000,000'> 25,000,000

# %%
for element in soup.find_all(class_='attribute'):
    print(element.text,'\n')
# Out:
# (estimated)
#
# (23 December 2016)
#
# (USA)
#
# (16 January 2017)

# %%
a = re.search(r'Release Date:</h4>[ ]+[0-9,a-z A-Z]+', page)
b = re.search(r'>[ ][0-9,a-z A-Z]+', a.group(0))
b.group(0)[1:]
# Out:
# ' 6 January 2017 '

# %%
a = re.search(r'Opening Weekend:</h4>[ ]+[$][0-9,]+', page)
b = re.search(r'[$][0-9,]+', a.group(0))
b.group(0)[1:]
# Out:
# '515,499'

# %%
for element in soup.find_all(itemprop='duration'):
    print(element.text,'\n')
# Out:
#                         2h 7min
#
#
#
#
#
#
# 127 min

# %%
for element in soup.find_all(itemprop='contentRating'):
    print(element.text,'\n')
# Out:
#
#
# Rated PG for thematic elements and some language

# %%
for element in soup.find_all(itemprop='awards'):
    print(element.text,'\n')
# Out:
#         Nominated for
#         2
#         Golden Globes.
#
#
#
#
#         Another
#       21 wins & 57 nominations.

# %%
for element in soup.find_all(class_='article'):
    print(element,'\n')
# Out:
# <div class="watchbar2 article">
# <div class="showtime full-table">
# <div class="winner-option watch-option " data-href="/showtimes/title/tt4846340?date=2017-01-17&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2425422342&amp;pf_rd_r=0CWJP4BCMBEXAR1CS50D&amp;pf_rd_s=center-2&amp;pf_rd_t=15021&amp;pf_rd_i=tt4846340&amp;ref_=tt_wbr_sh" title="In Theaters">
# <div class="watch-icon winner cinema" id="watchbar2">
# </div>
# <div class="info table-cell">
# <h2>
# <a class="segment-link " href="/showtimes/title/tt4846340?date=2017-01-17&amp;pf_rd_m=A2FGELUUNOQJNL&amp;pf_rd_p=2425422342&amp;pf_rd_r=0CWJP4BCMBEXAR1CS50D&amp;pf_rd_s=center-2&amp;pf_rd_t=15021&amp;pf_rd_i=tt4846340&amp;ref_=tt_wbr_sh"> Get Showtimes &amp; Tickets
# </a> </h2>
# <p>
#
#             In <span id="num_theaters">50 theaters near Newyork NY US
#                     <span class="fontsmall">
# ...

# %%
print(soup.find('titleDetails'))
# Out:
# None

# %%
soup.title.contents
# Out:
# ['Hidden Figures (2016) - IMDb']

# %%
soup.body.b
# Out:
# <b>
#         Nominated for
#         2
#         Golden Globes.
#       </b>

# %% [markdown]
# Metascore of each film is inside the a <div> of the class star-box-details.
# Do a .find for that and then you'll have to do some regular expressions to
# extract the exact piece you want (regular-expressions.info has a great
# tutorial on regex and if you really get into regex, you'll probably end up
# sinking hours into RexEgg).
# http://stackoverflow.com/questions/32749164/how-to-extract-budget-gross-metascore-from-imdb-using-scrapy-and-beautifulsoup
